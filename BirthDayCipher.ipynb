# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
image1 = np.loadtxt("image1.txt").reshape(2492, 1512, 3).astype(np.uint8)
image2 = np.loadtxt("image2.txt").reshape(2492, 1512, 3).astype(np.uint8)

# %% [markdown]
# # First image

# %%
plt.imshow(image1)
plt.show()

# %% [markdown]
# # Second image

# %%
plt.imshow(image2)
plt.show()

# %% [markdown]
# # What will you do with the two images :-) ?

# %%
result = np.ones(np.shape(image1)) # put something else here using image1 and image2

plt.imshow(result)
plt.show()
